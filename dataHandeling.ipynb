# %%
import pandas as pd

# %%
df = pd.read_csv("ardFlow.csv", encoding="cp1256")
df
# Out:
#         ost           river        ostan  station     sal   abi  ertefa  \
# 0      25.0  يدي بو ليك چاي  اردبيل  -25  عمو قين  1328.0  29.0  1385.0
# 1      25.0  يدي بو ليك چاي  اردبيل  -25  عمو قين  1328.0  29.0  1385.0
# 2      25.0  يدي بو ليك چاي  اردبيل  -25  عمو قين  1328.0  29.0  1385.0
# 3      25.0  يدي بو ليك چاي  اردبيل  -25  عمو قين  1328.0  29.0  1385.0
# 4      25.0  يدي بو ليك چاي  اردبيل  -25  عمو قين  1328.0  29.0  1385.0
# ...     ...             ...          ...      ...     ...   ...     ...
# 32728  25.0         دره رود  اردبيل  -25   مشيران  1397.0  98.0   705.0
# 32729  25.0         دره رود  اردبيل  -25   مشيران  1397.0  98.0   705.0
# 32730  25.0         دره رود  اردبيل  -25   مشيران  1397.0  98.0   705.0
# 32731  25.0         دره رود  اردبيل  -25   مشيران  1397.0  98.0   705.0
# 32732  25.0         دره رود  اردبيل  -25   مشيران  1397.0  98.0   705.0
#
#             arz      tool    code  ...    dey    bah    esf    far    ord  \
# ...

# %%
stationlist =  df['code'].unique()
print(stationlist)



stataions_df = {}
for code in stationlist:
    stataions_df[code] = df.loc[df['code'] == code]




# df.loc[df['code'] == 'code']
# df.loc[df['code'] == '19-022']
# Out:
# ['19-022' '19-055' '19-059' '19-097' '19-099' '19-101' '19-123' '19-149'
#  '19-150' '19-151' '19-152' '19-981' '17-133' '17-381' '17-875' '17-917'
#  '17-987' '17-155' '19-063' '19-065' '19-069' '19-873' '19-944' '19-949'
#  '19-002' '19-005' '19-071' '19-119' '19-121' '19-833' '19-901' '19-987'
#  '19-026' '19-049' '19-051' '19-053' '19-093' '19-095' '19-144' '19-148'
#  '19-910' '19-982' nan]

# %%
stataions_df['17-155']
# Out:
#         ost   river        ostan station     sal   abi  ertefa       arz  \
# 527    16.0  شاهرود  اردبيل  -25     شال  1348.0  49.0  1389.0  37-19-48
# 528    16.0  شاهرود  اردبيل  -25     شال  1348.0  49.0  1389.0  37-19-48
# 529    16.0  شاهرود  اردبيل  -25     شال  1348.0  49.0  1389.0  37-19-48
# 530    16.0  شاهرود  اردبيل  -25     شال  1348.0  49.0  1389.0  37-19-48
# 531    16.0  شاهرود  اردبيل  -25     شال  1348.0  49.0  1389.0  37-19-48
# ...     ...     ...          ...     ...     ...   ...     ...       ...
# 31767  25.0  شاهرود  اردبيل  -25     شال  1397.0  98.0  1388.0  37-19-47
# 31768  25.0  شاهرود  اردبيل  -25     شال  1397.0  98.0  1388.0  37-19-47
# 31769  25.0  شاهرود  اردبيل  -25     شال  1397.0  98.0  1388.0  37-19-47
# 31770  25.0  شاهرود  اردبيل  -25     شال  1397.0  98.0  1388.0  37-19-47
# 31771  25.0  شاهرود  اردبيل  -25     شال  1397.0  98.0  1388.0  37-19-47
#
#            tool    code  ...    dey    bah    esf   far    ord    khr    tir  \
# ...
